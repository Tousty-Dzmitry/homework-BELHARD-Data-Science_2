# %%
# !pip freeze > requirements.txt

# %%
import pandas as pd
print(f'Версия pandas: {pd.__version__}')
# Out:
# Версия pandas: 2.2.3

# %%
def load_data(file):
    return pd.read_csv(file)


df = load_data ('Number of Deaths by Risk Factors.csv')
load_data ('Number of Deaths by Risk Factors.csv')
# Out:
#            Entity Code  Year   Outdoor air pollution   \
# 0     Afghanistan  AFG  1990                     3169
# 1     Afghanistan  AFG  1991                     3222
# 2     Afghanistan  AFG  1992                     3395
# 3     Afghanistan  AFG  1993                     3623
# 4     Afghanistan  AFG  1994                     3788
# ...           ...  ...   ...                      ...
# 6835     Zimbabwe  ZWE  2015                     2835
# 6836     Zimbabwe  ZWE  2016                     2781
# 6837     Zimbabwe  ZWE  2017                     2700
# 6838     Zimbabwe  ZWE  2018                     2669
# 6839     Zimbabwe  ZWE  2019                     2680
#
#       High systolic blood pressure   Diet high in sodium  \
# 0                             25633                 1045
# 1                             25872                 1055
# 2                             26309                 1075
# 3                             26961                 1103
# 4                             27658                 1134
# ...                             ...                  ...
# 6835                          11483                 1063
# 6836                          11663                 1082
# 6837                          11819                 1098
# 6838                          12002                 1117
# 6839                          12241                 1140
#
#        Diet low in whole grains   Alcohol use   Diet low in fruits  \
# 0                           7077           356                3185
# 1                           7149           364                3248
# 2                           7297           376                3351
# 3                           7499           389                3480
# 4                           7698           399                3610
# ...                          ...           ...                 ...
# 6835                        1354          4854                1820
# 6836                        1383          4915                1854
# 6837                        1409          4992                1883
# 6838                        1439          5044                1917
# 6839                        1475          5156                1960
#
#       Unsafe water source  ...   High body-mass index    Unsafe sanitation  \
# 0                    3702  ...                    9518                2798
# 1                    4309  ...                    9489                3254
# 2                    5356  ...                    9528                4042
# 3                    7152  ...                    9611                5392
# 4                    7192  ...                    9675                5418
# ...                   ...  ...                     ...                 ...
# 6835                 4336  ...                    5636                2879
# 6836                 4244  ...                    5849                2798
# 6837                 4193  ...                    6047                2744
# 6838                 4013  ...                    6248                2608
# 6839                 3914  ...                    6475                2531
#
#        No access to handwashing facility   \
# 0                                    4825
# 1                                    5127
# 2                                    5889
# 3                                    7007
# 4                                    7421
# ...                                   ...
# 6835                                 4328
# 6836                                 4295
# 6837                                 4251
# 6838                                 4153
# 6839                                 4113
#
#        Drug use - Sex: Both - Age: All Ages (Number)  \
# 0                                                174
# 1                                                188
# 2                                                211
# 3                                                232
# 4                                                247
# ...                                              ...
# 6835                                            1068
# 6836                                            1042
# 6837                                            1007
# 6838                                             969
# 6839                                             963
#
#       Low bone mineral density   Vitamin A deficiency   Child stunting   \
# 0                          389                   2016              7686
# 1                          389                   2056              7886
# 2                          393                   2100              8568
# 3                          411                   2316              9875
# 4                          413                   2665             11031
# ...                        ...                    ...               ...
# 6835                       407                    138               730
# 6836                       415                    101               674
# 6837                       424                     82               629
# 6838                       434                     85               607
# 6839                       438                     81               585
#
#       Discontinued breastfeeding   Non-exclusive breastfeeding  \
# 0                             107                         2216
# 1                             121                         2501
# 2                             150                         3053
# 3                             204                         3726
# 4                             204                         3833
# ...                           ...                          ...
# 6835                           21                          734
# 6836                           20                          700
# 6837                           19                          678
# 6838                           17                          644
# 6839                           16                          631
#
#        Iron deficiency
# 0                  564
# 1                  611
# 2                  700
# 3                  773
# 4                  812
# ...                ...
# 6835               282
# 6836               275
# 6837               267
# 6838               261
# 6839               259
#
# [6840 rows x 31 columns]

# %%
def preprocess_data(countr):
    # df = df.dropna()
    # belarus = df.iloc[481:500] 
    country = df[df['Entity'] == countr]
    # belarus.to_csv('belarus.csv', index=False)
    # df = pd.read_csv('belarus.csv')
    return country

preprocess_data('China').to_csv('country.csv', index=False)

# %%
# Визуализация

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Загрузка данных
df = pd.read_csv('country.csv')
# Преобразование в словарь
column_dict = df.to_dict('list')

print("Все доступные ключи:", column_dict.keys())

def Deaths_by_Risk_Factors(a):
        
    factor_name = a
    
    # Пример DataFrame
    df = pd.DataFrame({
        'Year': column_dict['Year'][:],
        'Factor': column_dict[factor_name][:]
    })
    plt.title(factor_name, fontsize=14, pad=20)
    plt.xlabel('Год', fontsize=12, labelpad=10)
    plt.ylabel('Количество случаев', fontsize=12, labelpad=10)
    plt.bar(df['Year'], df['Factor'])
    
    return plt.show()
# Out:
# Все доступные ключи: dict_keys(['Entity', 'Code', 'Year', ' Outdoor air pollution ', 'High systolic blood pressure ', 'Diet high in sodium', ' Diet low in whole grains ', 'Alcohol use ', 'Diet low in fruits', 'Unsafe water source', 'Secondhand smoke', ' Low birth weight ', 'Child wasting  ', ' Unsafe sex ', 'Diet low in nuts and seeds ', ' Household air pollution from solid fuels', ' Diet low in vegetables ', 'Low physical activity', ' Smoking ', ' High fasting plasma glucose ', ' Air pollution ', ' High body-mass index ', ' Unsafe sanitation', ' No access to handwashing facility ', ' Drug use - Sex: Both - Age: All Ages (Number)', 'Low bone mineral density', ' Vitamin A deficiency', ' Child stunting ', 'Discontinued breastfeeding ', 'Non-exclusive breastfeeding', ' Iron deficiency'])

# %%
Deaths_by_Risk_Factors('Alcohol use ')        

Deaths_by_Risk_Factors('High systolic blood pressure ') 

Deaths_by_Risk_Factors(' Diet low in whole grains ') 

Deaths_by_Risk_Factors(' Smoking ')
